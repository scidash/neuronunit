# %%
#import pandas as pd
#df = pd.DataFrame(np.column_stack(np.array(vmpop[0].searched)))
#df.index = ['CPU 0','CPU 1','CPU 2','CPU 3', 'CPU 4', 'CPU 5', 'CPU 6']
#return df

import pickle

with open('rheoframe.p','rb') as handle:
    df2 = pickle.load(handle)

# %% [raw]
# df2

# %%
rheobase = 52.46913580246913

import seaborn as sns
cm = sns.light_palette("red",as_cmap=True)#,center=rheobase)
#cm.set_gamma = rheobase
s = df2.style.background_gradient(cmap=cm)#,center=rheobase)

s
# Out:
#         <style  type="text/css" >
#
#
#             #T_7c54d730_7f5f_11e7_ae2d_0242ac110004row0_col0 {
#
#                 background-color:  #ffe5e5;
#
#             }
#
#             #T_7c54d730_7f5f_11e7_ae2d_0242ac110004row0_col1 {
#
#                 background-color:  #ffe5e5;
#
#             }
#
#             #T_7c54d730_7f5f_11e7_ae2d_0242ac110004row0_col2 {
#
#                 background-color:  #ffe5e5;
#
#             }
#
#             #T_7c54d730_7f5f_11e7_ae2d_0242ac110004row0_col3 {
#
#                 background-color:  #ffe5e5;
#
#             }
#
#             #T_7c54d730_7f5f_11e7_ae2d_0242ac110004row1_col0 {
#
#                 background-color:  #ffc0c0;
#
#             }
#
#             #T_7c54d730_7f5f_11e7_ae2d_0242ac110004row1_col1 {
#
#                 background-color:  #ffc0c0;
#
#             }
#
#             #T_7c54d730_7f5f_11e7_ae2d_0242ac110004row1_col2 {
#
#                 background-color:  #ffc0c0;
#
#             }
#
# ...

# %% [markdown]
# dir(cm)

# %%
df2[0][1]
# Out:
# 41.666666666666664

# %%
import numpy as np

# %%
colors1 = [np.abs(rheobase)-np.abs(i) for i in df2[0]]

# %%
column1 = [i for i in df2[0]]

# %%
colors1
# Out:
# [52.469135802469133,
#  10.802469135802468,
#  -30.864197530864196,
#  -72.53086419753086,
#  -114.19753086419752,
#  -155.86419753086417,
#  -197.53086419753086]

# %%
import pandas as pd

# %%
#df1=pd.df(column1)
c1 = pd.DataFrame(np.array(column1))

# %%
#cm = sns.light_palette("red", as_cmap=True)
#color.append(np.abs(rheobase-x))
colors1 = [np.abs(rheobase)-np.abs(i) for i in df2[0]]
#ax = sns.heatmap(c1, cmap=colors1)
#s = c1.style.background_gradient(cmap=ax)#,center=rheobase)

# %%
df2
# Out:
#                 0          1          2          3
# CPU 0    0.000000  41.666667  48.611111  52.083333
# CPU 1   41.666667  48.611111  49.768519  52.469136
# CPU 2   83.333333  55.555556  50.925926  52.854938
# CPU 3  125.000000  62.500000  52.083333  53.240741
# CPU 4  166.666667  62.500000  52.083333  53.240741
# CPU 5  208.333333  76.388889  54.398148  54.012346
# CPU 6  250.000000  83.333333  55.555556  54.398148
