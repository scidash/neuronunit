# %%
from neuronunit.optimisation import get_neab
# Out:
# /usr/local/lib/python3.5/dist-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}

# %%
print(dir(get_neab))
# Out:
# ['RheobaseTestP', '_', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'anchor', 'copy', 'dm', 'do_use_cache', 'druckman2013', 'executable_druckman_tests', 'executable_tests', 'fi', 'get_common_criteria', 'get_obs', 'get_tests', 'json', 'neuroelectro', 'neuroelectro_summary_observation', 'neuronunit', 'os', 'passive', 'pickle', 'remake_tests', 'replace_zero_std', 'sciunit', 'substitute_criteria', 'substitute_parallel_for_serial', 'update_amplitude', 'urllib', 'waveform']

# %%
electro_obs = get_neab.do_use_cache()

# %%
from neuronunit.tests import fi, passive, waveform

test_classes = [ passive.RestingPotentialTest,
                 waveform.InjectedCurrentAPAmplitudeTest,
                 fi.RheobaseTest,
                 passive.TimeConstantTest,
                 passive.CapacitanceTest,
                 waveform.InjectedCurrentAPThresholdTest,
                 passive.InputResistanceTest,
                 waveform.InjectedCurrentAPWidthTest
                 ]
#,
local_tests = []
for eo in electro_obs:
    for i,t in enumerate(test_classes):
        for k,v in eo[1].items():
            print(v)
            try:
                temp=t(v)
                local_tests.append(temp)
            except:
                print('failed: ',k)
                #print(v)
                #print('failed: ',t(v).name)
            #local_tests.append()
            #print(v)
            #tests.append(t(v))
            #print(k,v)
    
    #
        
     #   print(eo[1])
        #temp_test = t(eo[1])
        #tests.append(temp_test)
#electro_obs[0][1]
local_tests
# Out:
# {'n': 1, 'std': array(0.53434592) * ms, 'mean': array(1.505) * ms}
# ({'n': 1, 'std': array(0.53434592) * ms, 'mean': array(1.505) * ms},) {}
# {'n': 1, 'std': array(6.53234788) * mV, 'mean': array(-57.9) * mV}
# ({'n': 1, 'std': array(6.53234788) * mV, 'mean': array(-57.9) * mV},) {}
# {'n': 8, 'std': array(8.77960968) * ms, 'mean': array(23.186875) * ms}
# ({'n': 8, 'std': array(8.77960968) * ms, 'mean': array(23.186875) * ms},) {}
# {'n': 11, 'std': array(5.49222298) * mV, 'mean': array(-41.47424242) * mV}
# ({'n': 11, 'std': array(5.49222298) * mV, 'mean': array(-41.47424242) * mV},) {}
# {'n': 2, 'std': array(1.865e-11) * F, 'mean': array(6.865e-11) * F}
# ({'n': 2, 'std': array(1.865e-11) * F, 'mean': array(6.865e-11) * F},) {}
# {'n': 1, 'std': array(77633160.8333564) * ohm, 'mean': array(4.57e+08) * ohm}
# ({'n': 1, 'std': array(77633160.8333564) * ohm, 'mean': array(4.57e+08) * ohm},) {}
# {'n': 1, 'std': array(12.74880304) * mV, 'mean': array(64.) * mV}
# ...

# %%
local_tests[1].observation
# Out:
# {'mean': None, 'std': None}

# %%
#get_neab
#tests = get_neab.remake_tests()

# %%
#tests = get_neab.get_tests()

# %%
tests
