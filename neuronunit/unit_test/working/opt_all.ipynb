# %%
from neuronunit.optimisation.optimization_management import TSD
"""Tests of NeuronUnit test classes"""
import unittest
import os
import sys
import dask
from dask import bag
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt

from itertools import repeat
import quantities as pq

import copy
import unittest
import pickle

import numpy as np
import pickle
import dask.bag as db
import os

from neuronunit.optimisation import get_neab
from neuronunit.optimisation.data_transport_container import DataTC

from neuronunit.optimisation.optimization_management import dtc_to_rheo#, mint_generic_model
from neuronunit.optimisation.optimization_management import OptMan,inject_and_plot_model

from neuronunit import tests as nu_tests, neuroelectro
from neuronunit.tests import passive, waveform, fi
from neuronunit.optimisation import exhaustive_search
from neuronunit.optimisation.model_parameters import MODEL_PARAMS
from neuronunit.tests import dynamics
from neuronunit.optimisation import data_transport_container

from neuronunit.tests.fi import RheobaseTest, RheobaseTestP
from neuronunit import aibs
from neuronunit.optimisation.optimisations import run_ga
from neuronunit.optimisation import model_parameters
from neuronunit.optimisation import mint_tests
from neuronunit.optimisation import get_neab
test_frame = get_neab.process_all_cells()
test_frame.pop('Olfactory bulb (main) mitral cell',None)
# Out:
# consider installing pynn a heavier backend
# INFO       Cache size for target "cython": 5047 MB.
# You can call "clear_cache('cython')" to delete all files from the cache or manually delete files in the "/home/russell/.cython/brian_extensions" directory. [brian2]
# INFO:root:test
# INFO:root:test
# pynn python Error

# %%
#easy_standards = {ut.name:ut.observation['std'] for ut in use_test.values()}

def permutations(use_test,backend):
    use_test = TSD(use_test)
    use_test.use_rheobase_score = True
    edges = model_parameters.MODEL_PARAMS[backend]
    ga_out = use_test.optimize(edges,backend=backend,protocol={'allen': False, 'elephant': True},\
       MU=5,NGEN=5,free_params=None,seed_pop=None,hold_constant=None)
    dtc = ga_out['pf'][0].dtc
    vm,plt = inject_and_plot_model(dtc.attrs,dtc.backend)
    plt.plot(vm.times,vm.magnitude)
    return dtc, ga_out['DO']
    
    
#backends = ["RAW","HH"]#,"ADEXP","BHH"]    
#for b in backends:
    
for t in test_frame.values():
    #print(t,b)
    break
    
dtc = permutations(test_frame['Neocortex pyramidal cell layer 5-6'],"HH")
# Out:
# Z = 2.15
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-54.18293732) * mV, 'std': array(13.4456978) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.00
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-87.82558852) * mV, 'std': array(1.59587507) * mV}
# {'amplitude': array(2.0985961) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(2.0985961) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = 0.00
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-68.23275797) * mV, 'std': array(4.14278553) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.03
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-88.02237569) * mV, 'std': array(0.19504117) * mV}
# {'amplitude': array(6.11686707) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(6.11686707) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.01
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-87.89047302) * mV, 'std': array(0.97969046) * mV}
# {'amplitude': array(4.56758738) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(4.56758738) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = 0.28
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-66.4003352) * mV, 'std': array(4.68051023) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.02
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-88.00687858) * mV, 'std': array(0.16181831) * mV}
# {'amplitude': array(10.00460386) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(10.00460386) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = 0.29
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-66.33740927) * mV, 'std': array(0.45450847) * mV}
# {'amplitude': array(2.20502615) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(2.20502615) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -2.96
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-87.56527966) * mV, 'std': array(7.40167643) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = 2.14
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-54.26426414) * mV, 'std': array(13.54219516) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -2.68
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-85.75221343) * mV, 'std': array(4.71628224) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -0.33
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-70.40002803) * mV, 'std': array(0.57345316) * mV}
# {'amplitude': array(4.16436195) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(4.16436195) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -0.06
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-68.62458438) * mV, 'std': array(0.71369056) * mV}
# {'amplitude': array(7.87056684) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(7.87056684) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -2.84
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-86.81537781) * mV, 'std': array(0.65655133) * mV}
# {'amplitude': array(4.94400859) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(4.94400859) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.02
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-88.00554099) * mV, 'std': array(0.16082765) * mV}
# {'amplitude': array(9.98166203) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(9.98166203) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -2.88
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-87.05687523) * mV, 'std': array(6.34285875) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = 2.22
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-53.71967408) * mV, 'std': array(2.77281456) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.03
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-88.02197995) * mV, 'std': array(0.17783284) * mV}
# {'amplitude': array(7.32802749) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(7.32802749) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.02
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-87.99232219) * mV, 'std': array(0.1370567) * mV}
# {'amplitude': array(8.69792104) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(8.69792104) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -2.96
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-87.57535279) * mV, 'std': array(6.16096768) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = 2.14
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-54.25007216) * mV, 'std': array(13.22418816) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.00
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-87.82885767) * mV, 'std': array(7.34585291) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.02
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-88.00728956) * mV, 'std': array(0.16192844) * mV}
# {'amplitude': array(10.47939062) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(10.47939062) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.03
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-88.02166023) * mV, 'std': array(0.19431711) * mV}
# {'amplitude': array(5.83198071) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(5.83198071) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -2.96
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-87.56527966) * mV, 'std': array(7.40167643) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.01
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-87.88184402) * mV, 'std': array(6.41098174) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = 2.26
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-53.51433847) * mV, 'std': array(2.80716286) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -2.65
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-85.54848514) * mV, 'std': array(0.26117637) * mV}
# {'amplitude': array(5.69145083) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(5.69145083) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -3.02
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-88.00687858) * mV, 'std': array(0.16181831) * mV}
# {'amplitude': array(10.00460386) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(10.00460386) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# Z = -2.96
# {'mean': array(-68.24814346) * mV, 'std': array(6.53234788) * mV, 'n': 79} {'mean': array(-87.56527966) * mV, 'std': array(7.40167643) * mV}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}
# {'amplitude': array(0.) * pA, 'delay': array(100.) * ms, 'duration': array(1000.) * ms}

# %%
#test_frame['']

# %%
from IPython.display import HTML, display
display(dtc.SM)
display(dtc.obs_preds)
# Out:
#  RheobaseTest InputResistanceTest TimeConstantTest CapacitanceTest  \
#     Z = -1.21           Z = 14.17        Z = -2.01       Z = -1.07
#
#  RestingPotentialTest InjectedCurrentAPWidthTest  \
#             Z = -0.06                  Z = -0.58
#
#  InjectedCurrentAPAmplitudeTest InjectedCurrentAPThresholdTest
#                       Z = -7.24                      Z = -0.17
#                                         RheobaseTest  \
# 0  {'mean': 213.849583333333 pA, 'std': 170.45245...
# 1                   {'value': 7.8705668449401855 pA}
#
#                                  InputResistanceTest  \
# 0  {'mean': 120.672073643411 Mohm, 'std': 77.6331...
# 1  {'value': 1220808581.3264458 kg*m**2/(s**3*A**2)}
#
#                                     TimeConstantTest  \
# 0  {'mean': 15.7342424242424 ms, 'std': 7.3116263...
# 1                 {'value': 0.0010085766293400553 s}
#
#                                      CapacitanceTest  \
# 0  {'mean': 150.584166666667 pF, 'std': 139.68388...
# 1  {'value': 8.261546034057248e-13 s**4*A**2/(kg*...
#
#                                 RestingPotentialTest  \
# 0  {'mean': -68.2481434599156 mV, 'std': 6.532347...
# 1  {'mean': -68.62458437765603 mV, 'std': 0.71369...
#
#                           InjectedCurrentAPWidthTest  \
# 0  {'mean': 1.20769387755102 ms, 'std': 0.5343459...
# 1  {'mean': 0.0009000069231301778 s, 'std': 0.0 s...
#
#                       InjectedCurrentAPAmplitudeTest  \
# 0  {'mean': 80.4351020408164 mV, 'std': 12.748803...
# 1  {'mean': -11.859699193469275 mV, 'std': 0.0 mV...
#
#                       InjectedCurrentAPThresholdTest
# 0  {'mean': -42.7357232704403 mV, 'std': 8.040732...
# 1  {'mean': -44.11589511812557 mV, 'std': 0.0 mV,...

# %%
#dir(dtc)

# %%
test_frame['Neocortex pyramidal cell layer 5-6']
