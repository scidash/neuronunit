# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import quantities as pq
import neuronunit.unit_test.test_tests as x
# Out:
# /Users/rgerkin/Dropbox/miniconda3/lib/python3.7/site-packages/airspeed/__init__.py:505: FutureWarning: Possible nested set at position 8
#   KEYVALSEP = re.compile(r'[ \t]*:[[ \t]*(.*)$', re.S)
# /Users/rgerkin/Dropbox/miniconda3/lib/python3.7/site-packages/pyNN/neuron/__init__.py:14: UserWarning: mpi4py not available
#   warnings.warn("mpi4py not available")
# Could not load PyNNBackend due to NEURON issues: NEURON mechanisms not found in /Users/rgerkin/Dropbox/miniconda3/lib/python3.7/site-packages/pyNN/neuron/nmodl. You may need to run 'nrnivmodl' in this directory.

# %% [markdown]
# ### Serial rheobase test

# %%
modelS, testS = x.quick_test_builder(test_class="RheobaseTest")
scoreS = testS.judge(modelS)
scoreS, scoreS.prediction
# Out:
# Getting Rheobase data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?nlex=nifext_50&e__name=Rheobase
# Highest subthreshold current is 51.5625 pA
# Lowest suprathreshold current is 52.1484375 pA
# (Ratio = 0.24, {'value': array(52.1484375) * pA})

# %%
scoreS.plot_vm()

# %% [markdown]
# ### Parallel rheobase test

# %%
modelP, testP = x.quick_test_builder(test_class="RheobaseTestP")
scoreP = testP.judge(modelP)
scoreP, scoreP.prediction
# Out:
# Getting Rheobase data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?nlex=nifext_50&e__name=Rheobase
# Getting rheobase vm
# (Ratio = 0.25, {'value': array(53.5234375) * pA})

# %%
scoreP.plot_vm()
