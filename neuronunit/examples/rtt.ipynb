# %%
# http://www.physics.usyd.edu.au/teach_res/mp/mscripts/
# ns_izh002.m
import collections
from collections import OrderedDict
import numpy as np

# Fast spiking cannot be reproduced as it requires modifications to the standard Izhi equation,
# which are expressed in this mod file.
# https://github.com/OpenSourceBrain/IzhikevichModel/blob/master/NEURON/izhi2007b.mod


reduced2007 = collections.OrderedDict([
  #              C    k     vr  vt vpeak   a      b   c    d  celltype
  ('RS',        (100, 0.7,  -60, -40, 35, 0.03,   -2, -50,  100,  1)),
  ('IB',        (150, 1.2,  -75, -45, 50, 0.01,   5, -56,  130,   2)),
  ('LTS',       (100, 1.0,  -56, -42, 40, 0.03,   8, -53,   20,   4)),
  ('TC',        (200, 1.6,  -60, -50, 35, 0.01,  15, -60,   10,   6)),
  ('TC_burst',  (200, 1.6,  -60, -50, 35, 0.01,  15, -60,   10,   6))])


type2007 = collections.OrderedDict([
  #              C    k     vr  vt vpeak   a      b   c    d  celltype
  ('RS',        (100, 0.7,  -60, -40, 35, 0.03,   -2, -50,  100,  1)),
  ('IB',        (150, 1.2,  -75, -45, 50, 0.01,   5, -56,  130,   2)),
  ('LTS',       (100, 1.0,  -56, -42, 40, 0.03,   8, -53,   20,   4)),
  ('TC',        (200, 1.6,  -60, -50, 35, 0.01,  15, -60,   10,   6)),
  ('TC_burst',  (200, 1.6,  -60, -50, 35, 0.01,  15, -60,   10,   6)),
  ('RTN',       (40,  0.25, -65, -45,  0, 0.015, 10, -55,   50,   7)),
  ('RTN_burst', (40,  0.25, -65, -45,  0, 0.015, 10, -55,   50,   7)),
  ('CH',        (50,  1.5,  -60, -40, 25, 0.03,   1, -40,  150,   3)),
  ('FS',        (20,  1.0,  -55, -40, 25, 0.2,   -2, -45,  -55,   5))])

reduced_dict = OrderedDict([(k,[]) for k in ['C','k','vr','vt','vPeak','a','b','c','d']])

#OrderedDict
for i,k in enumerate(reduced_dict.keys()):
    for v in type2007.values():
        reduced_dict[k].append(v[i])

explore_param = {k:(np.min(v),np.max(v)) for k,v in reduced_dict.items()}
param_ranges = OrderedDict(explore_param)


RS = {}
IB = {}
TC = {}
CH = {}
RTN_burst = {}
cells = OrderedDict([(k,[]) for k in ['RS','IB','CH','LTS','FS','TC','TC_burst','RTN','RTN_busrt']])
reduced_cells = OrderedDict([(k,[]) for k in ['RS','IB','LTS','TC','TC_burst']])

for index,key in enumerate(reduced_cells.keys()):
    reduced_cells[key] = {}
    for k,v in reduced_dict.items():
        reduced_cells[key][k] = v[index]

print(reduced_cells)
cells = reduced_cells
# Out:
# OrderedDict([('RS', {'C': 100, 'k': 0.7, 'vr': -60, 'vt': -40, 'vPeak': 35, 'a': 0.03, 'b': -2, 'c': -50, 'd': 100}), ('IB', {'C': 150, 'k': 1.2, 'vr': -75, 'vt': -45, 'vPeak': 50, 'a': 0.01, 'b': 5, 'c': -56, 'd': 130}), ('LTS', {'C': 100, 'k': 1.0, 'vr': -56, 'vt': -42, 'vPeak': 40, 'a': 0.03, 'b': 8, 'c': -53, 'd': 20}), ('TC', {'C': 200, 'k': 1.6, 'vr': -60, 'vt': -50, 'vPeak': 35, 'a': 0.01, 'b': 15, 'c': -60, 'd': 10}), ('TC_burst', {'C': 200, 'k': 1.6, 'vr': -60, 'vt': -50, 'vPeak': 35, 'a': 0.01, 'b': 15, 'c': -60, 'd': 10})])

# %%
model = None
from neuronunit.models.reduced import ReducedModel
from neuronunit.optimisation import get_neab

#from neuronunit.optimisation.model_parameters import model_params, path_params
#LEMS_MODEL_PATH = path_params['model_path']

#model = ReducedModel(LEMS_MODEL_PATH,name = str('vanilla'),backend = ('RAW'))
#model.set_attrs(cells['TC'])

# %%
tests_,all_tests, observation,suite = get_neab.get_tests()

rheobase = all_tests[0].generate_prediction(model)
print(rheobase)
# Out:
# {'id': 129, 'name': 'Olfactory bulb (main) mitral cell', 'neuron_db_id': 267, 'nlex_id': 'nlx_anat_100201'}
# Getting cell capacitance data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=cell+capacitance
# Getting input resistance data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=input+resistance
# Getting resting membrane potential data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=resting+membrane+potential
# Getting membrane time constant data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=membrane+time+constant
# Getting spike amplitude data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spike+amplitude
# Getting spike half-width data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spike+half-width
# Getting spike threshold data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spike+threshold
# Getting rheobase data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=rheobase
# Getting firing frequency data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=firing+frequency
# Getting AHP duration data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=AHP+duration
# Getting cell diameter data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=cell+diameter
# Getting access resistance data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=access+resistance
# Getting sag ratio data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=sag+ratio
# Getting cell surface area data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=cell+surface+area
# Getting AHP amplitude data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=AHP+amplitude
# Getting FI slope data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=FI+slope
# Getting spontaneous firing rate data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spontaneous+firing+rate
# Getting fast AHP amplitude data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=fast+AHP+amplitude
# Getting fast AHP duration data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=fast+AHP+duration
# Getting slow AHP amplitude data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=slow+AHP+amplitude
# Getting slow AHP duration data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=slow+AHP+duration
# Getting spike width data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spike+width
# Getting ADP amplitude data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=ADP+amplitude
# Getting ADP duration data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=ADP+duration
# Getting spike peak data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spike+peak
# Getting adaptation ratio data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=adaptation+ratio
# Getting first spike latency data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=first+spike+latency
# Getting other data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=other
# Getting spike rise time data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spike+rise+time
# Getting spike decay time data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spike+decay+time
# Getting spike max rise slope data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spike+max+rise+slope
# Getting spike max decay slope data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spike+max+decay+slope
# Getting sag amplitude data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=sag+amplitude
# Getting maximum firing rate data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=maximum+firing+rate
# Getting medium AHP amplitude data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=medium+AHP+amplitude
# Getting medium AHP duration data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=medium+AHP+duration
# Getting spike amplitude from resting data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spike+amplitude+from+resting
# Getting spike amplitude from trough data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=spike+amplitude+from+trough
# Getting AHP voltage data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=AHP+voltage
# Getting fast AHP voltage data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=fast+AHP+voltage
# Getting slow AHP voltage data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=slow+AHP+voltage
# Getting medium AHP voltage data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=medium+AHP+voltage
# Getting AHP amplitude from resting data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=AHP+amplitude+from+resting
# Getting fast AHP amplitude from resting data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=fast+AHP+amplitude+from+resting
# Getting slow AHP amplitude from resting data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=slow+AHP+amplitude+from+resting
# Getting medium AHP amplitude from resting data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=medium+AHP+amplitude+from+resting
# Getting adaptation ratio (last/first ISI) data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=adaptation+ratio+%28last%2Ffirst+ISI%29
# Getting adaptation percent (first/last ISI) data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=adaptation+percent+%28first%2Flast+ISI%29
# Getting adaptation percent (last/first ISI) data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=adaptation+percent+%28last%2Ffirst+ISI%29
# Getting adaptation ratio (1 – first/last ISI) data values from neuroelectro.org
# http://neuroelectro.org/api/1/nes/?n=129&nlex=nlx_anat_100201&n__name=Olfactory+bulb+%28main%29+mitral+cell&e__name=adaptation+ratio+%281+%E2%80%93+first%2Flast+ISI%29
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# ~/safe2/neuronunit/neuronunit/optimisation/get_neab.py in get_common_criteria()
#     364
# --> 365         anchor = os.path.dirname(anchor)
#     366         mypath = os.path.join(os.sep,anchor,'optimisation/all_tests.p')
#
# UnboundLocalError: local variable 'anchor' referenced before assignment
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-5ace00aba9ec> in <module>
# ----> 1 tests_,all_tests, observation,suite = get_neab.get_tests()
#       2
#       3 rheobase = all_tests[0].generate_prediction(model)
#       4 print(rheobase)
#
# ~/safe2/neuronunit/neuronunit/optimisation/get_neab.py in get_tests(backend)
#     404         with open(electro_path,'rb') as f:
#     405             electro_tests = pickle.load(f)
# --> 406     electro_tests = get_common_criteria()
#     407     electro_tests = replace_zero_std(electro_tests)
#     408     if backend in str('ADEXP'):
#
# ~/safe2/neuronunit/neuronunit/optimisation/get_neab.py in get_common_criteria()
#     376             print(p)
#     377             p_observations = get_obs(p)
# --> 378             p_tests = p(p_observations)
#     379             obs_frame[p["name"]] = p_observations#, p_tests))
#     380             test_frame[p["name"]] = p_tests#, p_tests))
#
# TypeError: 'dict' object is not callable

# %%
import pickle
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from neuronunit.models.reduced import ReducedModel
from neuronunit.optimization.model_parameters import model_params, path_params
LEMS_MODEL_PATH = path_params['model_path']
import neuronunit.optimization as opt
import quantities as pq

from neuronunit.optimization.data_transport_container import DataTC
model = ReducedModel(LEMS_MODEL_PATH,name = str('vanilla'),backend = ('RAW'))
model.set_attrs(cells['TC'])

iparams = {}
iparams['injected_square_current'] = {}
iparams['injected_square_current']['amplitude'] =75.36800000000001*pq.pA
#['amplitude']  = dtc.vtest[k]['injected_square_current']['amplitude']
DELAY = 100.0*pq.ms
DURATION = 1000.0*pq.ms
iparams['injected_square_current']['delay'] = DELAY
iparams['injected_square_current']['duration'] = int(DURATION)

model.inject_square_current(iparams)

plt.plot(model.get_membrane_potential().times,model.get_membrane_potential(),label='RAW')
plt.legend()
plt.show()

# %%
cnt = 0
scores = []
tests_,all_tests, observation,suite = opt.get_neab.get_tests()

# %%
def format_iparams(all_tests,rheobase):

    for t in all_tests[1:5]:
        DURATION = 500.0*pq.ms
        DELAY = 200.0*pq.ms

        obs = t.observation
        t.params = {}
        t.params['injected_square_current'] = {}
        t.params['injected_square_current']['delay']= DELAY
        t.params['injected_square_current']['duration'] = DURATION
        t.params['injected_square_current']['amplitude'] = -10*pq.pA
        
        
    for t in all_tests[-3::]:    
        t.params = {}
        DURATION = 1000.0*pq.ms
        DELAY = 100.0*pq.ms

        t.params['injected_square_current'] = {}
        t.params['injected_square_current']['delay']= DELAY
        t.params['injected_square_current']['duration'] = DURATION
        t.params['injected_square_current']['amplitude'] = rheobase['value']
    
    all_tests[0].params = all_tests[-1].params
    
    return all_tests

pt = format_iparams(all_tests,rheobase)
print([t.params['injected_square_current']['amplitude'] for t in pt[-3::] ])
print([t.params['injected_square_current']['amplitude'] for t in pt[0:5] ])

# %% [markdown]
# ##
# # * Get predictions from models.
# ## * Fake NeuroElectro Observations
# ## * Do roundtrip testing
# ##

# %%
predictions = []
import dask.bag as db
# The rheobase has been obtained seperately and cannot be db mapped.
# Nested DB mappings dont work.
ptbag = db.from_sequence(pt[1::])

def obtain_predictions(t):    
    model = None
    model = ReducedModel(LEMS_MODEL_PATH,name = str('vanilla'),backend = ('RAW'))
    model.set_attrs(cells['TC'])
    return t.generate_prediction(model)
predictions = list(ptbag.map(obtain_predictions).compute())
predictions.insert(0,rheobase)
print(predictions)

# %%
# having both means and values in dictionary makes it very irritating to iterate over.
# It's more harmless to demote means to values, than to elevate values to means.
# Simply swap key names: means, for values.
for p in predictions:
    if 'mean' in p.keys():
        p['value'] = p.pop('mean')
print(predictions)

# %%
# make some new tests based on internally generated data 
# as opposed to experimental data.


TC_tests = copy.copy(all_tests)
for ind,t in enumerate(TC_tests):
    if 'mean' in t.observation.keys():
        t.observation['value'] = t.observation.pop('mean')
    pred =  predictions[ind]['value']
    try:
        pred = pred.rescale(t.units)
        t.observation['value'] = pred
    except:        
        t.observation['value'] = pred
    t.observation['mean'] = t.observation['value']
        
    print(t.observation['value'])
    
pickle.dump(TC_tests,open('thalamo_cortical_tests.p','wb'))

# %%
from neuronunit.optimization import optimization_management as om
free_params = ['a','b','vr']#,'k','vt'] # this can only be odd numbers.

#
hc = {}
for k,v in cells['TC'].items():
    if k not in free_params:
        hc[k] = v
print(hc)
import pickle
TC_tests = pickle.load(open('thalamo_cortical_tests.p','rb'))    
ga_out, DO = om.run_ga(explore_param,5,TC_tests,free_params=free_params,hc = hc)

# %%
print(ga_out['dhof'][0].attrs)
print(cells['TC'])


model1 = None
model1 = ReducedModel(LEMS_MODEL_PATH,name = str('vanilla'),backend = ('RAW'))
model1.set_attrs(ga_out['dhof'][0].attrs)
model1.inject_square_current(iparams)

model2 = None
model2 = ReducedModel(LEMS_MODEL_PATH,name = str('vanilla'),backend = ('RAW'))
#vanilla = translate(mparams,m2m)
model2.set_attrs(cells['TC'])
model2.inject_square_current(iparams)


plt.plot(model1.get_membrane_potential().times,model1.get_membrane_potential(),label='optimizer result')
plt.plot(model2.get_membrane_potential().times,model2.get_membrane_potential(),label='ground truth')
plt.legend()

# %%
def hack_judge(test_and_models):
    (test, attrs) = test_and_models
    model = None
    obs = test.observation
    model = ReducedModel(LEMS_MODEL_PATH,name = str('vanilla'),backend = ('RAW'))
    model.set_attrs(attrs)
    test.generate_prediction(model)
    pred = test.generate_prediction(model)
    score = test.compute_score(obs,pred)
    try:
        print(obs['value'],pred['value'])
    except:
        print(obs['mean'],pred['mean'])
        
    return score

scores = []
for i,t in enumerate(TC_tests):
    test_and_models = (t,cells['TC'])
    score = hack_judge(test_and_models)
    scores.append(score)
print(scores[0].sort_key)    
print(scores[0])

# %%
ga_out.keys()
ga_out['dhof'][0].scores

# %%
print([s.sort_key for s in scores])
print([s.score for s in scores])

score = hack_judge((TC_tests[-3],cells['TC']))
print(score)

# %%
scores = []
for t in TC_tests:
    test_and_models = (t,cells['RS'])
    score = hack_judge(test_and_models)
    scores.append(score)
print(scores[0].sort_key)    
print(scores[0])
print([s.sort_key for s in scores])

# %%
import dask.bag as db
# The rheobase has been obtained seperately and cannot be db mapped.
# Nested DB mappings dont work.
from itertools import repeat
test_a_models = zip(TC_tests[1::],repeat(cells['RS']))
tc_bag = db.from_sequence(test_a_models)

scores = list(tc_bag.map(hack_judge).compute())
scores.insert(0,rheobase)
print(scores)

# %%
score = TC_tests[0].judge(model,stop_on_error = False, deep_error = True)
print(score.prediction)
#print(model.get_spike_count())

# %%
from neuronunit.optimization import optimization_management as opt
from neuronunit.models import ReducedModel
