# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.plot([0],[1])
plt.show()
from jupyter_core.paths import jupyter_data_dir

print(jupyter_data_dir())
import sys
import pickle
print(sys.executable)
from neuronunit.optimisation.optimization_management import inject_and_plot, nuunit_dm_evaluation, transform
import os

try:
    results = pickle.load(open('../unit_test/working/all_data_tests.p','rb'))
except:
    try:

        os.system('wget https://www.dropbox.com/s/cod7jz4yrr55dsw/all_data_tests.p?dl=0')
        results = pickle.load(open('../unit_test/working/all_data_tests.p?dl=0','rb'))
    except:
        import elephant_data_tests

        results = pickle.load(open('../unit_test/working/all_data_tests.p','rb'))
# Out:
# /Users/rjjarvis/Library/Jupyter
# /anaconda3/bin/python3
# /Users/rjjarvis/git/safe/neuronunit/neuronunit/optimisation/optimization_management.py:9: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-f6f36d73648c>", line 2, in <module>
#     import matplotlib.pyplot as plt
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   matplotlib.use('agg')
# consider installing pynn a heavier backend
# WARNING    /Users/rjjarvis/git/safe/neuronunit/neuronunit/models/backends/badexp.py:24: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-f6f36d73648c>", line 2, in <module>
#     import matplotlib.pyplot as plt
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   mpl.use('Agg')
#  [py.warnings]
# WARNING:py.warnings:/Users/rjjarvis/git/safe/neuronunit/neuronunit/models/backends/badexp.py:24: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-f6f36d73648c>", line 2, in <module>
#     import matplotlib.pyplot as plt
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   mpl.use('Agg')
#
# WARNING    /Users/rjjarvis/git/safe/neuronunit/neuronunit/tests/fi.py:32: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-f6f36d73648c>", line 2, in <module>
#     import matplotlib.pyplot as plt
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   mpl.use('Agg')
#  [py.warnings]
# WARNING:py.warnings:/Users/rjjarvis/git/safe/neuronunit/neuronunit/tests/fi.py:32: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-f6f36d73648c>", line 2, in <module>
#     import matplotlib.pyplot as plt
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   mpl.use('Agg')
#
# WARNING    /Users/rjjarvis/git/safe/neuronunit/neuronunit/tests/target_spike_current.py:31: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-f6f36d73648c>", line 2, in <module>
#     import matplotlib.pyplot as plt
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   mpl.use('Agg')
#  [py.warnings]
# WARNING:py.warnings:/Users/rjjarvis/git/safe/neuronunit/neuronunit/tests/target_spike_current.py:31: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'module://ipykernel.pylab.backend_inline' by the following code:
#   File "/anaconda3/lib/python3.6/runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "/anaconda3/lib/python3.6/runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "/anaconda3/lib/python3.6/site-packages/traitlets/config/application.py", line 658, in launch_instance
#     app.start()
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelapp.py", line 486, in start
#     self.io_loop.start()
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 127, in start
#     self.asyncio_loop.run_forever()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 422, in run_forever
#     self._run_once()
#   File "/anaconda3/lib/python3.6/asyncio/base_events.py", line 1432, in _run_once
#     handle._run()
#   File "/anaconda3/lib/python3.6/asyncio/events.py", line 145, in _run
#     self._callback(*self._args)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/platform/asyncio.py", line 117, in _handle_events
#     handler_func(fileobj, events)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 450, in _handle_events
#     self._handle_recv()
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 480, in _handle_recv
#     self._run_callback(callback, msg)
#   File "/anaconda3/lib/python3.6/site-packages/zmq/eventloop/zmqstream.py", line 432, in _run_callback
#     callback(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/tornado/stack_context.py", line 276, in null_wrapper
#     return fn(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 233, in dispatch_shell
#     handler(stream, idents, msg)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/ipkernel.py", line 208, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "/anaconda3/lib/python3.6/site-packages/ipykernel/zmqshell.py", line 537, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2662, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2785, in _run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2903, in run_ast_nodes
#     if self.run_code(code, result):
#   File "/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py", line 2963, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-1-f6f36d73648c>", line 2, in <module>
#     import matplotlib.pyplot as plt
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/pyplot.py", line 71, in <module>
#     from matplotlib.backends import pylab_setup
#   File "/anaconda3/lib/python3.6/site-packages/matplotlib/backends/__init__.py", line 16, in <module>
#     line for line in traceback.format_stack()
#
#
#   mpl.use('Agg')
# WARNING    /Users/rjjarvis/git/safe/neuronunit/neuronunit/optimisation/optimization_management.py:86: UserWarning: ASCII plot (gnu plot) plotting backend not available, consider installing
#   warnings.warn('ASCII plot (gnu plot) plotting backend not available, consider installing')
#  [py.warnings]
# WARNING:py.warnings:/Users/rjjarvis/git/safe/neuronunit/neuronunit/optimisation/optimization_management.py:86: UserWarning: ASCII plot (gnu plot) plotting backend not available, consider installing
#   warnings.warn('ASCII plot (gnu plot) plotting backend not available, consider installing')
#
# WARNING    /Users/rjjarvis/git/safe/neuronunit/neuronunit/optimisation/optimization_management.py:90: UserWarning: Blue brain feature extraction not available, consider installing
#   warnings.warn('Blue brain feature extraction not available, consider installing')
#  [py.warnings]
# WARNING:py.warnings:/Users/rjjarvis/git/safe/neuronunit/neuronunit/optimisation/optimization_management.py:90: UserWarning: Blue brain feature extraction not available, consider installing
#   warnings.warn('Blue brain feature extraction not available, consider installing')
# glif python Error

# %%
#result_RAW

# %%
import os
result_RAW = pickle.load(open('RAWall_data_tests.p','rb'))
result_ADEXP = pickle.load(open('ADEXPall_data_tests.p','rb'))
result_RAW = result_RAW['RAW']

electro_path = str(os.getcwd())+'/..//tests/russell_tests.p'

assert os.path.isfile(electro_path) == True
with open(electro_path,'rb') as f:
    (test_frame,obs_frame) = pickle.load(f)
filtered_tests = {key:val for key,val in test_frame.items()}
print(filtered_tests.keys())
from neuronunit.optimisation.optimization_management import OptMan,TSD, get_dtc_pop
from neuronunit.optimisation import model_parameters
# Out:
# dict_keys(['Cerebellum Purkinje cell', 'Olfactory bulb (main) mitral cell', 'Hippocampus CA1 pyramidal cell', 'Neocortex pyramidal cell layer 5-6', 'Hippocampus CA1 basket cell'])

# %%
type(result_ADEXP['ADEXP']['olf'][0])
# Out:
# neuronunit.optimisation.optimization_management.WSListIndividual

# %%
# Out:
# True
# True

# %%
try:
    assert hasattr(result_ADEXP['ADEXP']['olf'][0],'dtc')

except:
    
    #result_ADEXP
    if not hasattr(result_ADEXP['ADEXP']['olf'][0],'dtc'):
        dtcdic, DO = get_dtc_pop(result_ADEXP,filtered_tests,model_parameters)

    ad_olf_dtc = [d for d in dtcdic['olf']][0]
    ad_purkine_dtc = [d for d in dtcdic['purkine']][0]
    ad_ca1pyr_dtc = [d for d in dtcdic['ca1pyr']][0]
    ad_ca1basket_dtc = [d for d in dtcdic['ca1basket']][0]
    ad_neo_dtc = [d for d in dtcdic['neo']][0]

    print(ad_purkine_dtc.attrs)
    
    
#model = ad_purkine_dtc.dtc_to_model()
#dtcdic
# Out:
# {'ADAPTATION_TIME_CONSTANT_tau_w': 112.5, 'ADAPTATION_VOLTAGE_COUPLING_a': 0.4375, 'C': 0.875, 'FIRING_THRESHOLD_v_spike': -30.0, 'MEMBRANE_RESISTANCE_R': 0.4375, 'MEMBRANE_TIME_SCALE_tau_m': 4.375, 'RHEOBASE_THRESHOLD_v_rh': -56.25, 'SHARPNESS_delta_T': 1.75, 'SPIKE_TRIGGERED_ADAPTATION_INCREMENT_b': 6.125, 'V_RESET': -57.375, 'V_REST': -70.0, 'b': 0.07875, 'peak_v': 0.001}
# {'olf': [<neuronunit.optimisation.data_transport_container.DataTC at 0x1c2a70e0b8>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c26a21cc0>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1054188d0>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c315b9b00>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c29d66588>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c27ac32b0>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c2c972390>],
#  'purkine': [<neuronunit.optimisation.data_transport_container.DataTC at 0x1c2e3fd710>],
#  'ca1pyr': [<neuronunit.optimisation.data_transport_container.DataTC at 0x1c2a70ee48>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x106082b00>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c259a1a20>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c2cee5550>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c28c85f60>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c2ceffe80>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c2be7add8>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c2b76cd68>],
#  'ca1basket': [<neuronunit.optimisation.data_transport_container.DataTC at 0x1c213ee438>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c213b4b70>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c26a21c88>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c315b9e10>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c259a1c18>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c213b4588>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c2c94cba8>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c213dc358>],
#  'neo': [<neuronunit.optimisation.data_transport_container.DataTC at 0x1c2a14efd0>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c259a1c50>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c213b4d30>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c213b4d68>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c29d7bb00>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c213b4e10>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c213b45f8>,
#   <neuronunit.optimisation.data_transport_container.DataTC at 0x1c213b4dd8>]}

# %%
#for k,v in enumerate(result_RAW['RAW'].items()):
#print(k)
RAW_dtc = None
#ADEXP_dtc = None
olf_dtc = [d for d in result_RAW['olf']][0]
purkine_dtc = [d for d in result_RAW['purkine']][0]
ca1pyr_dtc = [d for d in result_RAW['ca1pyr']][0]
ca1basket_dtc = [d for d in result_RAW['ca1basket']][0]
neo_dtc = [d for d in result_RAW['neo']][0]

#neo_dtc = [d for d in result_RAW['neo']][0]

vm = inject_and_plot([olf_dtc],second_pop=[ad_olf_dtc],third_pop=[ad_olf_dtc])
vm = inject_and_plot([ca1basket_dtc],second_pop=[ad_ca1basket_dtc],third_pop=[ad_ca1basket_dtc])
vm = inject_and_plot([neo_dtc],second_pop=[ad_neo_dtc],third_pop=[ad_neo_dtc])
vm = inject_and_plot([ca1pyr_dtc],second_pop=[ad_ca1pyr_dtc],third_pop=[ad_ca1pyr_dtc])
vm = inject_and_plot([purkine_dtc],second_pop=[ad_purkine_dtc],third_pop=[ad_purkine_dtc])


vm = inject_and_plot([olf_dtc],second_pop=[ad_olf_dtc],third_pop=[ad_olf_dtc],snippets=True)
vm = inject_and_plot([ca1basket_dtc],second_pop=[ad_ca1basket_dtc],third_pop=[ad_ca1basket_dtc],snippets=True)
vm = inject_and_plot([neo_dtc],second_pop=[ad_neo_dtc],third_pop=[ad_neo_dtc],snippets=True)
vm = inject_and_plot([ca1pyr_dtc],second_pop=[ad_ca1pyr_dtc],third_pop=[ad_ca1pyr_dtc],snippets=True)
vm = inject_and_plot([purkine_dtc],second_pop=[ad_purkine_dtc],third_pop=[ad_purkine_dtc],snippets=True)

#vm = inject_and_plot([olf_dtc],second_pop=[ad_olf_dtc],third_pop=[ad_olf_dtc],snippets=True)
#vm = inject_and_plot([ca1basket_dtc],second_pop=[ad_ca1basket_dtc],third_pop=[ad_ca1basket_dtc],snippets=True)
# Out:
# module://ipykernel.pylab.backend_inline
# module://ipykernel.pylab.backend_inline
# module://ipykernel.pylab.backend_inline
# module://ipykernel.pylab.backend_inline
# module://ipykernel.pylab.backend_inline
# module://ipykernel.pylab.backend_inline
# module://ipykernel.pylab.backend_inline
# module://ipykernel.pylab.backend_inline
# module://ipykernel.pylab.backend_inline
# module://ipykernel.pylab.backend_inline

# %%
RAW = {str(str(k).split('_RAW')[0]):v for k,v in results.items() if "_RAW" in k}
ADEXP = {str(str(k).split('_ADEXP')[0]):v for k,v in results.items() if "_ADEXP" in k}

# %%
RAW.keys()
ADEXP.keys()
# Out:
# dict_keys(['Cerebellum Purkinje cell', 'Olfactory bulb (main) mitral cell', 'Hippocampus CA1 pyramidal cell', 'Neocortex pyramidal cell layer 5-6', 'Hippocampus CA1 basket cell'])

# %%
for k in RAW.keys():
    print(k)
    RAW_dtc = None
    ADEXP_dtc = None
    RAW_dtc = [d.dtc for d in RAW[k]]
    
    ADEXP_dtc = [d.dtc for d in ADEXP[k]]
    vm = inject_and_plot(RAW_dtc,second_pop=ADEXP_dtc)
    vm = inject_and_plot(RAW_dtc,second_pop=ADEXP_dtc,snippets=True)
# Out:
# Cerebellum Purkinje cell
# Olfactory bulb (main) mitral cell
# Hippocampus CA1 pyramidal cell
# Neocortex pyramidal cell layer 5-6
# Hippocampus CA1 basket cell

# %%
vm = inject_and_plot(RAW_dtc,second_pop=ADEXP_dtc)

# %%
vm = inject_and_plot(RAW_dtc,second_pop=ADEXP_dtc,snippets=True)

# %%
import pandas as pd
df1 = pd.DataFrame([RAW_dtc[0].scores])
df1= df1.rename(index={0: str('Izhikivitch')})

# %%
df0 = pd.DataFrame([ADEXP_dtc[0].scores])
df0 = df0.rename(index={0: str('ADEXP')})

#df0.index[0] = str('ADEXP')

# %%
df2 = df0.append(df1)
df3 = df2.T

# %%
#fig.gca().set_ylabel(r'$\lambda$')

# %%
df3
# Out:
#                                    ADEXP  Izhikivitch
# CapacitanceTest                 0.225694     0.052786
# InjectedCurrentAPAmplitudeTest  0.011707     0.035871
# InjectedCurrentAPThresholdTest  0.053162     0.053127
# InjectedCurrentAPWidthTest      0.027397     0.008059
# InputResistanceTest             0.123931     1.000000
# RestingPotentialTest            0.006060     0.015485
# RheobaseTest                    1.000000     0.001483
# TimeConstantTest                0.048135     0.050954

# %%
compare0 = {t.name:t.observation for t in RAW_dtc[0].tests }
compare0 = {k:(v,RAW_dtc[0].predictions[k]) for k,v in compare0.items() }

# %%
compare1 = {t.name:t.observation for t in ADEXP_dtc[0].tests }
compare1 = {k:(v,RAW_dtc[0].predictions[k]) for k,v in compare1.items() }

# %%
pre_df = {}
def format_nice_frame(compare0):
    for k,v in compare0.items():
        temp = v[0][list(v[0].keys())[0]].rescale(v[1][list(v[1].keys())[0]].units)
        pre_df[k] = (temp,v[1][list(v[1].keys())[0]],v[0]['std'].rescale(v[1][list(v[1].keys())[0]].units))
        df6=pd.DataFrame([pre_df])    

    return df6  
df6 = format_nice_frame(compare0)

# %% [markdown]
# # compare observations and predictions:

# %%
df7 = format_nice_frame(compare1)#compare1
df7
# Out:
#                                      CapacitanceTest  \
# 0  (1.7100000000000004e-11 s**4*A**2/(kg*m**2), 1...
#
#                       InjectedCurrentAPAmplitudeTest  \
# 0  (0.07702800000000001 V, 0.025065258421045285 V...
#
#                       InjectedCurrentAPThresholdTest  \
# 0  (-49.019999999999996 mV, -0.02426894132413728 ...
#
#                         InjectedCurrentAPWidthTest  \
# 0  (0.00066 s, 0.00076 s, 0.0005602255943601558 s)
#
#                                  InputResistanceTest  \
# 0  (25630000.0 kg*m**2/(s**3*A**2), 7176641082.72...
#
#                            RestingPotentialTest  \
# 0  (-0.079 V, -0.056 V, 0.028746585311335674 V)
#
#                                         RheobaseTest  \
# 0  (0.04 pA, 0.038884732413180245 pA, 364.3693541...
#
#                                     TimeConstantTest
# 0  (0.0205 s, 0.0008492994382773672 s, 0.01925354...

# %%
df6
# Out:
#                                      CapacitanceTest  \
# 0  (1.7100000000000004e-11 s**4*A**2/(kg*m**2), 1...
#
#                       InjectedCurrentAPAmplitudeTest  \
# 0  (0.07702800000000001 V, 0.025065258421045285 V...
#
#                       InjectedCurrentAPThresholdTest  \
# 0  (-49.019999999999996 mV, -0.02426894132413728 ...
#
#                         InjectedCurrentAPWidthTest  \
# 0  (0.00066 s, 0.00076 s, 0.0005602255943601558 s)
#
#                                  InputResistanceTest  \
# 0  (25630000.0 kg*m**2/(s**3*A**2), 7176641082.72...
#
#                            RestingPotentialTest  \
# 0  (-0.079 V, -0.056 V, 0.028746585311335674 V)
#
#                                         RheobaseTest  \
# 0  (0.04 pA, 0.038884732413180245 pA, 364.3693541...
#
#                                     TimeConstantTest
# 0  (0.0205 s, 0.0008492994382773672 s, 0.01925354...

# %% [markdown]
# # Look at where the optimized cells reside in druckman feature space

# %%
print(RAW_dtc[0].attrs)
print(RAW_dtc[-1].attrs)
# Out:
# {'C': 200, 'a': 0.01, 'b': 15, 'c': -60, 'd': 150, 'dt': 0.005, 'k': 1.6, 'vPeak': 25, 'vr': -56, 'vt': -50, 'Iext': array([0., 0., 0., ..., 0., 0., 0.])}
# {'C': 50, 'a': 0.03, 'b': 15, 'c': -40, 'd': 150, 'dt': 0.005, 'k': 1.6, 'vPeak': 50, 'vr': -56, 'vt': -40, 'Iext': array([0., 0., 0., ..., 0., 0., 0.])}

# %% [markdown]
# # Do this in parallel to save time

# %%
import dask.bag as db
bagged = db.from_sequence(RAW_dtc)
druckman_feature_coordinates_izhi = list(bagged.map(nuunit_dm_evaluation).compute())
izhidfeatures = [d.dm_test_features for d in druckman_feature_coordinates_izhi ]
druck0 = pd.DataFrame([izhidfeatures[0]])

# %%
druck0 = druck0.rename(index={0: str('Izhikivitch')})

# %%
import dask.bag as db
bagged = db.from_sequence(ADEXP_dtc)
druckman_feature_coordinatesadexp = list(bagged.map(nuunit_dm_evaluation).compute())
dfeatures = [d.dm_test_features for d in druckman_feature_coordinatesadexp ]
druck1 = pd.DataFrame([dfeatures[0]])

# %%
druck1
druck1 = druck1.rename(index={0: str('ADEXP')})

# %%
druck4 = pd.DataFrame([izhidfeatures[-1]])
druck4 = druck4.rename(index={0: str('Izhi_last')})

# %%
druck3 = pd.DataFrame([dfeatures[-1]])
druck3 = druck3.rename(index={0: str('ADEXP_last')})
#druck3.T

# %%
druck2 = druck1
druck2 = druck2.append(druck0)
druck2 = druck2.append(druck3)
druck2 = druck2.append(druck4)

# %%
# A function to convert all cells containing array (or other things) into floats.  
def f(x):
    try:
        return np.mean(x)
    except:
        try:
            return np.mean(x['pred'])
        except:
            print(x)
            raise e
d2 = druck2.fillna(0).applymap(f)
d2 = druck2.fillna(0).applymap(f)

druck2.T
# Out:
#                                                                         ADEXP  \
# AP12AHPDepthPercentChangeTest                             [0.0 dimensionless]
# AP12AmplitudeChangePercentTest                                           None
# AP12AmplitudeDropTest                                                 [0.0 V]
# AP12HalfWidthChangePercentTest                                           None
# AP12RateOfChangePeakToTroughPercentChangeTest              -0.0 dimensionless
# AP1AHPDepthTest                                       [0.11737500000000001 V]
# AP1AmplitudeTest                                                         None
# AP1DelayMeanStrongStimTest                              2.9999999999998863 ms
# AP1DelayMeanTest                                                       6.0 ms
# AP1DelaySDStrongStimTest                                               0.0 ms
# AP1DelaySDTest                                                         0.0 ms
# AP1RateOfChangePeakToTroughTest                                  -117.375 V/s
# AP1SSAmplitudeChangeTest                                                 None
# AP1WidthHalfHeightTest                                                   None
# AP1WidthPeakToTroughTest                                             [0.0 ms]
# AP2AHPDepthTest                                       [0.11737500000000001 V]
# AP2AmplitudeTest                                                         None
# AP2DelayMeanStrongStimTest                                             6.0 ms
# AP2DelayMeanTest                                        10.999999999999886 ms
# AP2DelaySDStrongStimTest                                               0.0 ms
# AP2DelaySDTest                                                         0.0 ms
# AP2RateOfChangePeakToTroughTest                                  -117.375 V/s
# AP2WidthHalfHeightTest                                                   None
# AP2WidthPeakToTroughTest                                             [0.0 ms]
# AccommodationAtSSMeanTest                                            -24.3702
# AccommodationRateMeanAtSSTest                            104.3819185488864 ms
# AccommodationRateToSSTest                                                None
# Burst1ISIMeanStrongStimTest                                            3.0 ms
# Burst1ISIMeanTest                                                      5.0 ms
# Burst1ISISDStrongStimTest                                              0.0 ms
# Burst1ISISDTest                                                        0.0 ms
# ISIBurstMeanChangeTest                                            4.54747e-12
# ISICVTest                                                             15.8501
# ISIMedianTest                                                          7.0 ms
# InitialAccommodationMeanTest                                         -29.5082
# InputResistanceTest                            0.00035109842040301784 megaohm
# SSAccommodationMeanTest                                                  -100
# SpikeRateStrongStimTest                                              183.5 Hz
#
#                                                                 Izhikivitch  \
# AP12AHPDepthPercentChangeTest                                          None
# AP12AmplitudeChangePercentTest                                         None
# AP12AmplitudeDropTest                                                  None
# AP12HalfWidthChangePercentTest                                         None
# AP12RateOfChangePeakToTroughPercentChangeTest                          None
# AP1AHPDepthTest                                     [0.04230801795873634 V]
# AP1AmplitudeTest                                     [0.0449971147505705 V]
# AP1DelayMeanStrongStimTest                            27.480000000000246 ms
# AP1DelayMeanTest                                        52.5300000000002 ms
# AP1DelaySDStrongStimTest                                             0.0 ms
# AP1DelaySDTest                                                       0.0 ms
# AP1RateOfChangePeakToTroughTest                [-0.006842095039914334 V/ms]
# AP1SSAmplitudeChangeTest                                               None
# AP1WidthHalfHeightTest                                0.6450000000000001 ms
# AP1WidthPeakToTroughTest                            [12.759999999999991 ms]
# AP2AHPDepthTest                                                        None
# AP2AmplitudeTest                                                       None
# AP2DelayMeanStrongStimTest                            163.12000000000012 ms
# AP2DelayMeanTest                                                       None
# AP2DelaySDStrongStimTest                                             0.0 ms
# AP2DelaySDTest                                                         None
# AP2RateOfChangePeakToTroughTest                                        None
# AP2WidthHalfHeightTest                                                 None
# AP2WidthPeakToTroughTest                                               None
# AccommodationAtSSMeanTest                                              None
# AccommodationRateMeanAtSSTest                                          None
# AccommodationRateToSSTest                                              None
# Burst1ISIMeanStrongStimTest                           145.50749999999994 ms
# Burst1ISIMeanTest                                                      None
# Burst1ISISDStrongStimTest                                            0.0 ms
# Burst1ISISDTest                                                        None
# ISIBurstMeanChangeTest                                                 None
# ISICVTest                                                              None
# ISIMedianTest                                                          None
# InitialAccommodationMeanTest                                           -100
# InputResistanceTest                             0.03866867284177757 megaohm
# SSAccommodationMeanTest                                                -100
# SpikeRateStrongStimTest                                              6.5 Hz
#
#                                                                    ADEXP_last  \
# AP12AHPDepthPercentChangeTest                             [0.0 dimensionless]
# AP12AmplitudeChangePercentTest                                           None
# AP12AmplitudeDropTest                                                 [0.0 V]
# AP12HalfWidthChangePercentTest                                           None
# AP12RateOfChangePeakToTroughPercentChangeTest              -0.0 dimensionless
# AP1AHPDepthTest                                       [0.11737500000000001 V]
# AP1AmplitudeTest                                                         None
# AP1DelayMeanStrongStimTest                              2.9999999999998863 ms
# AP1DelayMeanTest                                         6.999999999999886 ms
# AP1DelaySDStrongStimTest                                               0.0 ms
# AP1DelaySDTest                                                         0.0 ms
# AP1RateOfChangePeakToTroughTest                                  -117.375 V/s
# AP1SSAmplitudeChangeTest                                                 None
# AP1WidthHalfHeightTest                                                   None
# AP1WidthPeakToTroughTest                                             [0.0 ms]
# AP2AHPDepthTest                                       [0.11737500000000001 V]
# AP2AmplitudeTest                                                         None
# AP2DelayMeanStrongStimTest                               4.999999999999886 ms
# AP2DelayMeanTest                                        10.999999999999886 ms
# AP2DelaySDStrongStimTest                                               0.0 ms
# AP2DelaySDTest                                                         0.0 ms
# AP2RateOfChangePeakToTroughTest                                  -117.375 V/s
# AP2WidthHalfHeightTest                                                   None
# AP2WidthPeakToTroughTest                                             [0.0 ms]
# AccommodationAtSSMeanTest                                        -1.16977e-07
# AccommodationRateMeanAtSSTest                           10.320569440366112 ms
# AccommodationRateToSSTest                                                None
# Burst1ISIMeanStrongStimTest                                            2.0 ms
# Burst1ISIMeanTest                                                      4.0 ms
# Burst1ISISDStrongStimTest                                              0.0 ms
# Burst1ISISDTest                                                        0.0 ms
# ISIBurstMeanChangeTest                                                      0
# ISICVTest                                                                None
# ISIMedianTest                                                          4.0 ms
# InitialAccommodationMeanTest                                         -24.2424
# InputResistanceTest                            3.0710240328701956e-05 megaohm
# SSAccommodationMeanTest                                                  -100
# SpikeRateStrongStimTest                                              269.5 Hz
#
#                                                                           Izhi_last
# AP12AHPDepthPercentChangeTest                     [97.41618789814706 dimensionless]
# AP12AmplitudeChangePercentTest                 [-0.03770611835311821 dimensionless]
# AP12AmplitudeDropTest                                     [2.638808816415872e-05 V]
# AP12HalfWidthChangePercentTest                     2.9411764705882377 dimensionless
# AP12RateOfChangePeakToTroughPercentChangeTest    [-99.91242872261871 dimensionless]
# AP1AHPDepthTest                                             [0.02001642885371021 V]
# AP1AmplitudeTest                                             [0.0699835711462898 V]
# AP1DelayMeanStrongStimTest                                       3.5300000000002 ms
# AP1DelayMeanTest                                               7.975000000000023 ms
# AP1DelaySDStrongStimTest                                                     0.0 ms
# AP1DelaySDTest                                                               0.0 ms
# AP1RateOfChangePeakToTroughTest                           [-18.00000000001637 V/ms]
# AP1SSAmplitudeChangeTest                                                       None
# AP1WidthHalfHeightTest                                                      0.17 ms
# AP1WidthPeakToTroughTest                                 [0.0049999999999954525 ms]
# AP2AHPDepthTest                                             [0.03951567079633947 V]
# AP2AmplitudeTest                                            [0.06995718305812564 V]
# AP2DelayMeanStrongStimTest                                     6.080000000000041 ms
# AP2DelayMeanTest                                               16.19000000000017 ms
# AP2DelaySDStrongStimTest                                                     0.0 ms
# AP2DelaySDTest                                                               0.0 ms
# AP2RateOfChangePeakToTroughTest                         [-0.01576282992864857 V/ms]
# AP2WidthHalfHeightTest                                       0.17500000000000002 ms
# AP2WidthPeakToTroughTest                                      [6.94500000000005 ms]
# AccommodationAtSSMeanTest                                                      None
# AccommodationRateMeanAtSSTest                                                  None
# AccommodationRateToSSTest                                                      None
# Burst1ISIMeanStrongStimTest                                   3.2875000000000227 ms
# Burst1ISIMeanTest                                                              None
# Burst1ISISDStrongStimTest                                                    0.0 ms
# Burst1ISISDTest                                                                None
# ISIBurstMeanChangeTest                                                         None
# ISICVTest                                                                      None
# ISIMedianTest                                                  8.215000000000146 ms
# InitialAccommodationMeanTest                                                   -100
# InputResistanceTest                                    0.024166926643356942 megaohm
# SSAccommodationMeanTest                                                        -100
# SpikeRateStrongStimTest                                                     47.5 Hz

# %%
#results['Cerebellum Purkinje cell_RAW'] 
cwd = os.getcwd()
import numpy as np

# %%
# Open the 1.5x rheobase file
filename = os.path.join(cwd,'onefive_df.pkl')
with open(filename, 'rb') as f:
    df = pickle.load(f)
    
df.iloc[0][192:195]

'''
# in order to find out what is seperating and what is not.
del df['InputResistanceTest_1.5x']
del df['InputResistanceTest_3.0x']
del df['ohmic_input_resistance_1.5x']
del df['ohmic_input_resistance_3.0x']
del df['time_1.5x']                              
#       0.190362
del df['decay_time_constant_after_stim_3.0x']
del df['voltage_deflection_3.0x']
del df['steady_state_hyper_3.0x']
del df['steady_state_voltage_stimend_3.0x']
del df['voltage_deflection_vb_ssse_3.0x']
del df['sag_amplitude_3.0x']
#0.198310
del df['is_not_stuck_1.5x']
'''    


# Apply this function to each dataframe in order to convert all cells into floats.
# Also call fillna() first to impute missing values with 0's.  
df = df.fillna(0).applymap(f)

# %%
df
# Out:
#              AHP1_depth_from_peak_1.5x  AHP2_depth_from_peak_1.5x  \
# 313861539                    81.937500                  78.406255
# 313861677                    97.718750                  98.093750
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# 313862167                    59.406250                  57.343754
# ...                                ...                        ...
# NMLCL001510                  71.062000                  70.691200
# NMLCL001512                 123.268994                   0.000000
# NMLCL001513                  64.985064                  67.187107
# NMLCL001514                 110.123240                   0.000000
# NMLCL001515                  63.753765                  64.352717
# NMLCL001516                  70.347840                  71.138887
# NMLCL001519                  87.981354                  87.607795
# NMLCL001521                  79.424150                  83.491180
# NMLCL001522                  79.455300                  82.073331
# NMLCL001524                  77.122867                  75.592088
# NMLCL001525                  86.058868                  86.368464
# NMLCL001526                  77.510079                  77.257317
# NMLCL001527                 113.163358                  97.836696
# NMLCL001530                 108.901854                  84.082478
# NMLCL001531                  78.559632                  76.598034
# NMLCL001532                  69.348414                  70.396893
# NMLCL001533                  70.259938                  65.615626
# NMLCL001534                  41.370815                   0.000000
# NMLCL001535                  93.331008                  86.646087
# NMLCL001537                  84.608200                  83.990954
# NMLCL001538                  45.444712                  53.227800
# NMLCL001539                  77.938974                  79.432514
# NMLCL001540                   0.000000                   0.000000
# NMLCL001541                  85.267360                  78.169996
# NMLCL001542                  82.910243                  84.607800
# NMLCL001594                 110.800480                  99.497152
# NMLCL001650                  84.876732                  84.949020
# NMLCL001657                  93.718460                  93.535342
# NMLCL001660                 105.456050                 106.078701
# NMLCL001663                  84.876732                  84.949020
#
#              AHP_depth_1.5x  AHP_depth_abs_1.5x  AHP_depth_abs_slow_1.5x  \
# 313861539         -2.933358          -62.173892               -46.142664
# 313861677         16.759498          -54.223959               -54.843754
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# 313862167         20.566763          -58.314641               -56.035212
# ...                     ...                 ...                      ...
# NMLCL001510       19.161274          -60.346800               -61.235409
# NMLCL001512      -18.111907         -104.719994                 0.000000
# NMLCL001513       18.766912          -67.278846               -67.282182
# NMLCL001514      -10.376475          -97.683000                 0.000000
# NMLCL001515       16.732936          -63.468058               -57.459879
# NMLCL001516       27.987754          -62.375092               -62.392764
# NMLCL001519       20.904429          -62.925559               -63.036909
# NMLCL001521       23.436796          -69.331113               -69.536059
# NMLCL001522       23.152952          -63.508666               -62.164504
# NMLCL001524       24.737845          -66.685594               -66.656307
# NMLCL001525       19.944147          -65.770415               -65.774583
# NMLCL001526       29.351225          -62.963822               -62.997343
# NMLCL001527        9.346645          -73.488288               -73.068699
# NMLCL001530       13.200513          -70.410528               -65.491638
# NMLCL001531       11.291635          -72.891540               -72.158661
# NMLCL001532       11.242463          -66.158645               -66.205799
# NMLCL001533       23.701007          -64.963173               -65.587457
# NMLCL001534       17.627844          -61.972815                 0.000000
# NMLCL001535       19.488897          -69.767760                 0.000000
# NMLCL001537       10.159940          -70.150957               -69.473595
# NMLCL001538       26.081466          -42.253579               -36.304040
# NMLCL001539       14.758474          -73.789397               -71.522313
# NMLCL001540        0.000000            0.000000                 0.000000
# NMLCL001541       23.979409          -59.519476               -60.117691
# NMLCL001542       17.431797          -68.862808               -68.941676
# NMLCL001594        7.884422          -67.300704               -67.316695
# NMLCL001650       10.006138          -49.993861               -49.484261
# NMLCL001657        1.909754          -54.090244               -54.092049
# NMLCL001660       18.443589          -56.556407               -56.607916
# NMLCL001663       10.006138          -49.993861               -49.484261
#
#              AHP_depth_diff_1.5x  AHP_depth_from_peak_1.5x  \
# 313861539               0.016723                 73.104168
# 313861677              -0.075001                 97.270835
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# 313862167               0.049479                 56.880994
# ...                          ...                       ...
# NMLCL001510            -0.009321                 70.690494
# NMLCL001512             0.000000                123.268994
# NMLCL001513            -0.031756                 66.501983
# NMLCL001514             0.000000                110.123240
# NMLCL001515            -0.000052                 65.109186
# NMLCL001516             0.007434                 69.614376
# NMLCL001519            -0.081503                 86.823279
# NMLCL001521            -0.273888                 87.615447
# NMLCL001522             0.201579                 72.428236
# NMLCL001524             0.039968                 73.074852
# NMLCL001525             0.006079                 82.428773
# NMLCL001526            -0.009896                 75.768828
# NMLCL001527            -0.018020                102.167926
# NMLCL001530             6.186496                 88.630754
# NMLCL001531             0.008046                 77.855322
# NMLCL001532            -0.058466                 71.271509
# NMLCL001533             0.826416                 63.648952
# NMLCL001534             0.000000                 41.370815
# NMLCL001535             0.459746                 89.988547
# NMLCL001537            -0.041041                 85.460908
# NMLCL001538            -0.029269                 59.345519
# NMLCL001539            -0.025325                 79.729724
# NMLCL001540             0.000000                  0.000000
# NMLCL001541             0.922422                 75.177784
# NMLCL001542            -0.451446                 90.396731
# NMLCL001594            -0.025300                107.634615
# NMLCL001650            -0.000334                 84.803729
# NMLCL001657            -0.001995                 93.523120
# NMLCL001660            -0.055470                106.129995
# NMLCL001663            -0.000334                 84.803729
#
#              AHP_slow_time_1.5x  AHP_time_from_peak_1.5x  AP1_amp_1.5x  \
# 313861539              0.610583                 0.543548     66.625000
# 313861677              0.109934                 9.866667     83.437504
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# 313862167              0.190261                 1.613699     42.781250
# ...                         ...                      ...           ...
# NMLCL001510            0.300761                23.314286     59.525739
# NMLCL001512            0.000000                58.000000     74.521585
# NMLCL001513            0.178730                 4.474286     54.319041
# NMLCL001514            0.000000                45.000000     66.915611
# NMLCL001515            0.460683                 1.792778      0.000000
# NMLCL001516            0.231517                 8.848077     55.578457
# NMLCL001519            0.183572                16.186957     77.320275
# NMLCL001521            0.270454                20.965217     71.976765
# NMLCL001522            0.247093                 2.989474     62.041720
# NMLCL001524            0.085602                 5.056000     59.766739
# NMLCL001525            0.092996                 8.154545     68.610346
# NMLCL001526            0.068733                11.261538     61.716450
# NMLCL001527            0.210427                 8.829091     87.070450
# NMLCL001530            0.103457                30.880000     67.213900
# NMLCL001531            0.123241                 3.421739     58.702075
# NMLCL001532            0.349755                15.391111     59.500229
# NMLCL001533            0.420299                17.970000     55.038867
# NMLCL001534            0.000000                 1.300000     56.742129
# NMLCL001535            0.000000                11.000000     72.356698
# NMLCL001537            0.115775                 2.669767     72.266615
# NMLCL001538            0.479610                 1.567935     74.692252
# NMLCL001539            0.198820                 2.656410     60.189580
# NMLCL001540            0.000000                 0.000000      0.000000
# NMLCL001541            0.460905                 7.922727     72.550929
# NMLCL001542            0.425460                16.841667     80.931283
# NMLCL001594            0.255448                 5.538043     91.054451
# NMLCL001650            0.033616                 0.100000      0.000000
# NMLCL001657            0.077519                16.911111      0.000000
# NMLCL001660            0.160918                24.358333     17.179461
# NMLCL001663            0.033616                 0.100000      0.000000
#
#                 ...      threshold_v_3.0x  trough_index_3.0x  trough_t_3.0x  \
# 313861539       ...            -40.813828      398485.038610       1.992425
# 313861677       ...            -38.721155      294622.769231       1.473114
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# 313862167       ...            -39.840803      393670.245283       1.968351
# ...             ...                   ...                ...            ...
# NMLCL001510     ...              0.000000           0.000000       0.000000
# NMLCL001512     ...            -54.383224      305605.000000       3.056050
# NMLCL001513     ...            -53.030840      169495.666667       1.694957
# NMLCL001514     ...            -53.948303      204552.500000       2.045525
# NMLCL001515     ...              0.000000           0.000000       0.000000
# NMLCL001516     ...            -47.906929      204438.942623       2.044389
# NMLCL001519     ...              0.000000           0.000000       0.000000
# NMLCL001521     ...            -53.460893      184350.645161       1.843506
# NMLCL001522     ...              0.000000           0.000000       0.000000
# NMLCL001524     ...              0.000000           0.000000       0.000000
# NMLCL001525     ...              0.000000           0.000000       0.000000
# NMLCL001526     ...            -47.430878      202951.493151       2.029515
# NMLCL001527     ...              0.000000           0.000000       0.000000
# NMLCL001530     ...            -47.348592      234458.428571       2.344584
# NMLCL001531     ...              0.000000           0.000000       0.000000
# NMLCL001532     ...            -53.557273      195881.781513       1.958818
# NMLCL001533     ...            -53.440394      206709.500000       2.067095
# NMLCL001534     ...            -66.601918      201211.000000       2.012110
# NMLCL001535     ...            -47.589212      201216.287037       2.012163
# NMLCL001537     ...            -53.818324      199290.100000       1.992901
# NMLCL001538     ...              0.000000           0.000000       0.000000
# NMLCL001539     ...              0.000000           0.000000       0.000000
# NMLCL001540     ...              0.000000           0.000000       0.000000
# NMLCL001541     ...            -49.175567      169089.666667       1.690897
# NMLCL001542     ...            -52.713916      213213.734177       2.132137
# NMLCL001594     ...            -41.629275      197876.146067       1.978761
# NMLCL001650     ...              0.000000           0.000000       0.000000
# NMLCL001657     ...              0.000000           0.000000       0.000000
# NMLCL001660     ...              0.000000           0.000000       0.000000
# NMLCL001663     ...              0.000000           0.000000       0.000000
#
#              trough_v_3.0x  upstroke_3.0x  upstroke_downstroke_ratio_3.0x  \
# 313861539       -62.822636     384.396994                        1.116407
# 313861677       -56.141828     337.069923                        5.005307
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# 313862167       -56.923645     182.445244                        1.691332
# ...                    ...            ...                             ...
# NMLCL001510       0.000000       0.000000                        0.000000
# NMLCL001512    -103.839990     509.396297                        4.976192
# NMLCL001513     -68.262796     197.231547                        2.745921
# NMLCL001514     -97.684500     259.017828                        3.320583
# NMLCL001515       0.000000       0.000000                        0.000000
# NMLCL001516     -61.982036     249.358381                        3.272815
# NMLCL001519       0.000000       0.000000                        0.000000
# NMLCL001521     -65.492350     585.104462                        4.127003
# NMLCL001522       0.000000       0.000000                        0.000000
# NMLCL001524       0.000000       0.000000                        0.000000
# NMLCL001525       0.000000       0.000000                        0.000000
# NMLCL001526     -60.735093     226.327741                        4.361093
# NMLCL001527       0.000000       0.000000                        0.000000
# NMLCL001530     -71.340986     346.165895                        4.282579
# NMLCL001531       0.000000       0.000000                        0.000000
# NMLCL001532     -64.528487     251.082340                        4.111817
# NMLCL001533     -78.346360     184.401305                        3.062242
# NMLCL001534     -74.920379     149.695696                        1.449477
# NMLCL001535     -66.997210     371.399595                        4.283875
# NMLCL001537     -69.800651     508.450622                        3.429087
# NMLCL001538       0.000000       0.000000                        0.000000
# NMLCL001539       0.000000       0.000000                        0.000000
# NMLCL001540       0.000000       0.000000                        0.000000
# NMLCL001541     -69.621338     342.743910                        4.789356
# NMLCL001542     -61.334567     530.197965                        7.741342
# NMLCL001594     -50.215627     189.448764                        3.573727
# NMLCL001650       0.000000       0.000000                        0.000000
# NMLCL001657       0.000000       0.000000                        0.000000
# NMLCL001660       0.000000       0.000000                        0.000000
# NMLCL001663       0.000000       0.000000                        0.000000
#
#              upstroke_index_3.0x  upstroke_t_3.0x  upstroke_v_3.0x  width_3.0x
# 313861539          398335.579151         1.991678       -11.120053    0.000270
# 313861677          275428.769231         1.377144         1.182692    0.001150
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# 313862167          393169.443396         1.965847       -21.279776    0.000570
# ...                          ...              ...              ...         ...
# NMLCL001510             0.000000         0.000000         0.000000    0.000000
# NMLCL001512        101414.000000         1.014140       -14.240152    0.000860
# NMLCL001513        101329.666667         1.013297       -25.885266    0.000640
# NMLCL001514        196270.500000         1.962705       -10.458634    0.001320
# NMLCL001515             0.000000         0.000000         0.000000    0.000000
# NMLCL001516        204036.229508         2.040362       -12.544196    0.000815
# NMLCL001519             0.000000         0.000000         0.000000    0.000000
# NMLCL001521        182913.983871         1.829140       -17.223698    0.000442
# NMLCL001522             0.000000         0.000000         0.000000    0.000000
# NMLCL001524             0.000000         0.000000         0.000000    0.000000
# NMLCL001525             0.000000         0.000000         0.000000    0.000000
# NMLCL001526        201714.986301         2.017150        -9.826106    0.001104
# NMLCL001527             0.000000         0.000000         0.000000    0.000000
# NMLCL001530        230120.571429         2.301206        -6.591847    0.000911
# NMLCL001531             0.000000         0.000000         0.000000    0.000000
# NMLCL001532        195257.806723         1.952578       -19.854576    0.000876
# NMLCL001533        102082.000000         1.020820       -12.425157    0.000935
# NMLCL001534        100403.000000         1.004030       -29.471183    0.000480
# NMLCL001535        200682.268519         2.006823        -5.238970    0.000825
# NMLCL001537        199028.800000         1.990288       -14.992901    0.000470
# NMLCL001538             0.000000         0.000000         0.000000    0.000000
# NMLCL001539             0.000000         0.000000         0.000000    0.000000
# NMLCL001540             0.000000         0.000000         0.000000    0.000000
# NMLCL001541        101302.333333         1.013023        -4.775447    0.000797
# NMLCL001542        212439.613924         2.124396       -21.020338    0.000825
# NMLCL001594        197246.308989         1.972463        -1.280648    0.001215
# NMLCL001650             0.000000         0.000000         0.000000    0.000000
# NMLCL001657             0.000000         0.000000         0.000000    0.000000
# NMLCL001660             0.000000         0.000000         0.000000    0.000000
# NMLCL001663             0.000000         0.000000         0.000000    0.000000
#
# [7285 rows x 466 columns]

# %%
print("There are %d models+data and %d features" % df.shape)

# %%
# Turn all features into Normal(0,1) variables
# Important since features all have different scales
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
df[:] = ss.fit_transform(df.values)
df.groupby(df.index).first()
df = pd.DataFrame.drop_duplicates(df)
print(len(df))

# %%
# Check to see what is there.  Might also check to see if there is data there.
#df_30x#.head()

# make model dataframe
model_idx = [idx for idx in df.index.values if type(idx)==str]
model_no_trans_df = df[df.index.isin(model_idx)]
model_no_trans_df.index.name = 'Cell_ID'
model_df = model_no_trans_df.copy()
model_df.index.name = 'Cell_ID'

# make experiment dataframe
experiment_idx = [idx for idx in df.index.values if type(idx)==int]
experiment_no_trans_df = df[df.index.isin(experiment_idx)]
experiment_df = experiment_no_trans_df.copy()
print(len(experiment_df))

# %%
#print(len(experiment_df))
experiment_df = pd.DataFrame.drop_duplicates(experiment_df)
#experiment_df.index
experiment_df.groupby(experiment_df.index).first()
len(experiment_df)

# %%
print(len(model_df))
model_df = pd.DataFrame.drop_duplicates(model_df)
model_df.index
model_df.groupby(model_df.index).first()
len(model_df)

# %%
# Do PCA and look at variance explained
pca = PCA()
pca.fit(df.values)
n_features = df.shape[1]
plt.plot(range(1,n_features+1),pca.explained_variance_ratio_.cumsum())
plt.xlim(0,50);
plt.xlabel('Number of principal components')
plt.ylabel('Fraction of variance explained');

# %%
# THe transformed values, ordered from highest to lowest variance dimensions
transformed = pca.transform(df.values)


#model_idx = [idx for idx in enumerate(df.index.values) if type(idx)==str]
'''
#label_model_no_trans_df
model_no_trans_df.index.name = 'Cell_ID'
model_df = model_no_trans_df.copy()
model_df.index.name = 'Cell_ID'
'''
# make experiment dataframe
experiment_idx = [idx for idx in df.index.values if type(idx)==int]
model_no_trans_df = df[~df.index.isin(experiment_idx)]
experiment_idx_labels = [(i,idx) for i,idx in enumerate(df.index.values) if type(idx)==int]

#model_df
#df.labels
model_no_trans_df
experiment_idx_labels = [i[0] for i in experiment_idx_labels]
experiment_idx_labels
model_no_trans_df
model_index_labels = ~df.index.isin(experiment_idx)

model_index_labels
