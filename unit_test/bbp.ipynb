# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from neuronunit import bbp # The Blue Brain project module
# Out:
# /home/rgerkin/miniconda3/lib/python3.6/site-packages/cerberus/validator.py:1402: UserWarning: No validation schema is defined for the arguments of rule 'iterable'
#   "'%s'" % method_name.split('_', 2)[-1])

# %%
# Get the list of all available curated cells
cell_ids = bbp.list_curated_data()

# Get the name of the first cell
this_cell_id = cell_ids[0]

# Download the data for this cells from BBP (or use the previously downloaded data)
data = bbp.get_curated_data(this_cell_id)

# Get all the sweeps for this cell
all_sweeps = bbp.list_sweeps(this_cell_id)

# Get the fifth sweep
sweep_num = 5
fifth_sweep = all_sweeps[sweep_num - 1]
this_sweep = data[fifth_sweep]

# Plot the 
bbp.plot_data(this_sweep)
# Out:
# Getting data from http://microcircuits.epfl.ch/data/released_data/B95.zip
