# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
from neuronunit import bbp
data_id = bbp.list_curated_data()[0]
data = bbp.get_curated_data(data_id)
fifth_sweep = bbp.list_sweeps(data_id)[4]
bbp.plot_data(data[fifth_sweep])
# Out:
# Getting data from http://microcircuits.epfl.ch/data/released_data/B95.zip
# <img src="data:image/png;base64,..." width="640">
